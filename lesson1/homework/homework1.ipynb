# %% [markdown]
# ## Домашнее задание к уроку 1

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Подберите скорость обучения (eta) и количество итераций

# %%
import numpy as np

X = np.array([[ 1,  1],
              [ 1,  1],
              [ 1,  2],
              [ 1,  5],
              [ 1,  3],
              [ 1,  0],
              [ 1,  5],
              [ 1, 10],
              [ 1,  1],
              [ 1,  2]])

# %%
y = [45, 55, 50, 55, 60, 35, 75, 80, 50, 60]

# %%
def calc_mse(y, y_pred):
    err = np.mean((y - y_pred)**2)
    return err

# %%
n = X.shape[1]

eta = 1e-2
n_iter = 700

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    for k in range(W.shape[0]):
        W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    if i % 10 == 0:
        eta /= 1.1
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 2
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #10: W_new = [18.77319138  8.6270072 ], MSE = 398.58
# Iteration #20: W_new = [27.15289315  7.06014716], MSE = 207.1
# Iteration #30: W_new = [32.4241672   6.10426679], MSE = 124.63
# Iteration #40: W_new = [35.85213314  5.48265802], MSE = 86.53
# Iteration #50: W_new = [38.15155609  5.06569312], MSE = 67.79
# Iteration #60: W_new = [39.73790007  4.7780341 ], MSE = 58.04
# Iteration #70: W_new = [40.86051023  4.57446606], MSE = 52.69
# Iteration #80: W_new = [41.67349173  4.4270444 ], MSE = 49.62
# Iteration #90: W_new = [42.2746909  4.3180262], MSE = 47.78
# Iteration #100: W_new = [42.727794    4.23586294], MSE = 46.63
# Iteration #110: W_new = [43.07521157  4.17286412], MSE = 45.89
# Iteration #120: W_new = [43.34578807  4.12379924], MSE = 45.4
# Iteration #130: W_new = [43.55952748  4.08504089], MSE = 45.06
# Iteration #140: W_new = [43.73055537  4.05402762], MSE = 44.82
# Iteration #150: W_new = [43.8690146   4.02892018], MSE = 44.65
# Iteration #160: W_new = [43.9823022   4.00837722], MSE = 44.53
# Iteration #170: W_new = [44.0758912   3.99140629], MSE = 44.44
# Iteration #180: W_new = [44.15388587  3.97726316], MSE = 44.36
# Iteration #190: W_new = [44.21940291  3.96538266], MSE = 44.31
# Iteration #200: W_new = [44.27483692  3.95533056], MSE = 44.26
# Iteration #210: W_new = [44.32204803  3.94676955], MSE = 44.23
# Iteration #220: W_new = [44.36249605  3.93943492], MSE = 44.2
# Iteration #230: W_new = [44.39733771  3.93311693], MSE = 44.18
# Iteration #240: W_new = [44.42749793  3.92764784], MSE = 44.16
# Iteration #250: W_new = [44.45372252  3.92289241], MSE = 44.14
# Iteration #260: W_new = [44.47661773  3.91874072], MSE = 44.13
# Iteration #270: W_new = [44.49668006  3.91510272], MSE = 44.12
# Iteration #280: W_new = [44.51431902  3.91190417], MSE = 44.11
# Iteration #290: W_new = [44.5298746  3.9090834], MSE = 44.1
# Iteration #300: W_new = [44.54363088  3.90658891], MSE = 44.1
# Iteration #310: W_new = [44.55582661  3.90437741], MSE = 44.09
# Iteration #320: W_new = [44.56666354  3.9024123 ], MSE = 44.09
# Iteration #330: W_new = [44.57631309  3.9006625 ], MSE = 44.08
# Iteration #340: W_new = [44.5849216   3.89910148], MSE = 44.08
# Iteration #350: W_new = [44.59261455  3.89770648], MSE = 44.07
# Iteration #360: W_new = [44.59950005  3.8964579 ], MSE = 44.07
# Iteration #370: W_new = [44.60567159  3.89533879], MSE = 44.07
# Iteration #380: W_new = [44.61121033  3.89433442], MSE = 44.06
# Iteration #390: W_new = [44.61618698  3.89343199], MSE = 44.06
# Iteration #400: W_new = [44.62066334  3.89262027], MSE = 44.06
# Iteration #410: W_new = [44.62469361  3.89188944], MSE = 44.06
# Iteration #420: W_new = [44.62832542  3.89123087], MSE = 44.06
# Iteration #430: W_new = [44.6316008   3.89063693], MSE = 44.06
# Iteration #440: W_new = [44.63455687  3.89010089], MSE = 44.06
# Iteration #450: W_new = [44.63722652  3.88961679], MSE = 44.05
# Iteration #460: W_new = [44.63963895  3.88917933], MSE = 44.05
# Iteration #470: W_new = [44.64182013  3.88878381], MSE = 44.05
# Iteration #480: W_new = [44.64379322  3.88842602], MSE = 44.05
# Iteration #490: W_new = [44.64557886  3.88810222], MSE = 44.05
# Iteration #500: W_new = [44.64719553  3.88780906], MSE = 44.05
# Iteration #510: W_new = [44.64865977  3.88754355], MSE = 44.05
# Iteration #520: W_new = [44.64998639  3.88730298], MSE = 44.05
# Iteration #530: W_new = [44.6511887   3.88708496], MSE = 44.05
# Iteration #540: W_new = [44.65227866  3.88688732], MSE = 44.05
# Iteration #550: W_new = [44.653267    3.88670809], MSE = 44.05
# Iteration #560: W_new = [44.65416343  3.88654554], MSE = 44.05
# Iteration #570: W_new = [44.65497665  3.88639808], MSE = 44.05
# Iteration #580: W_new = [44.65571452  3.88626427], MSE = 44.05
# Iteration #590: W_new = [44.65638416  3.88614285], MSE = 44.05
# Iteration #600: W_new = [44.65699195  3.88603263], MSE = 44.05
# Iteration #610: W_new = [44.6575437   3.88593258], MSE = 44.05
# Iteration #620: W_new = [44.65804463  3.88584174], MSE = 44.05
# Iteration #630: W_new = [44.65849949  3.88575926], MSE = 44.05
# Iteration #640: W_new = [44.65891255  3.88568436], MSE = 44.05
# Iteration #650: W_new = [44.65928769  3.88561634], MSE = 44.05
# Iteration #660: W_new = [44.65962842  3.88555455], MSE = 44.05
# Iteration #670: W_new = [44.65993792  3.88549843], MSE = 44.05
# Iteration #680: W_new = [44.66021908  3.88544744], MSE = 44.04
# Iteration #690: W_new = [44.66047451  3.88540112], MSE = 44.04

# %% [markdown]
# ## Задание 2

# %% [markdown]
# В этом коде мы избавляемся от итераций по весам, но тут есть ошибка, исправьте ее

# %%
n = X.shape[1]

eta = 1e-2
n_iter = 130

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
#     for k in range(W.shape[0]):
#         W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    # ИЗМЕНЕНИЯ
    W -= eta * (1/n * 2 * np.dot(y_pred - y, X))
    print(f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')
# Out:
# Number of objects = 2
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #1: W_new = [5.605 4.535], MSE = 2038.48
# Iteration #2: W_new = [ 9.334 15.144], MSE = 1438.69
# Iteration #3: W_new = [9.5074 6.599 ], MSE = 1074.2
# Iteration #4: W_new = [12.22696 12.52848], MSE = 845.69
# Iteration #5: W_new = [12.89572   7.561976], MSE = 696.44
# Iteration #6: W_new = [14.9875552 10.8379008], MSE = 594.01
# Iteration #7: W_new = [15.88742944  7.91720288], MSE = 519.8
# Iteration #8: W_new = [17.57352563  9.69172915], MSE = 463.05
# Iteration #9: W_new = [18.55865432  7.9437319 ], MSE = 417.54
# Iteration #10: W_new = [19.96966932  8.87179137], MSE = 379.6
# Iteration #11: W_new = [20.96116498  7.79884524], MSE = 347.05
# Iteration #12: W_new = [22.17539491  8.25245884], MSE = 318.53
# Iteration #13: W_new = [23.13211776  7.57066034], MSE = 293.21
# Iteration #14: W_new = [24.19770788  7.76090243], MSE = 270.51
# Iteration #15: W_new = [25.09966637  7.30805593], MSE = 250.04
# Iteration #16: W_new = [26.04728295  7.35446094], MSE = 231.52
# Iteration #17: W_new = [26.88621637  7.03769246], MSE = 214.71
# Iteration #18: W_new = [27.736287    7.00775037], MSE = 199.45
# Iteration #19: W_new = [28.51033319  6.77368864], MSE = 185.56
# Iteration #20: W_new = [29.27719328  6.70531799], MSE = 172.93
# Iteration #21: W_new = [29.98787855  6.52311942], MSE = 161.42
# Iteration #22: W_new = [30.68215487  6.43745284], MSE = 150.95
# Iteration #23: W_new = [31.33270353  6.28913655], MSE = 141.41
# Iteration #24: W_new = [31.96269221  6.19779335], MSE = 132.73
# Iteration #25: W_new = [32.55708499  6.07273699], MSE = 124.82
# Iteration #26: W_new = [33.12955539  5.98195861], MSE = 117.61
# Iteration #27: W_new = [33.67201227  5.87376235], MSE = 111.05
# Iteration #28: W_new = [34.19268233  5.78676267], MSE = 105.07
# Iteration #29: W_new = [34.6873853   5.69146143], MSE = 99.62
# Iteration #30: W_new = [35.16120834  5.60976141], MSE = 94.66
# Iteration #31: W_new = [35.61215908  5.52480451], MSE = 90.15
# Iteration #32: W_new = [36.04350182  5.44898912], MSE = 86.03
# Iteration #33: W_new = [36.4544549   5.37265707], MSE = 82.28
# Iteration #34: W_new = [36.84721229  5.30280358], MSE = 78.87
# Iteration #35: W_new = [37.22164999  5.23387381], MSE = 75.76
# Iteration #36: W_new = [37.57932285  5.16979334], MSE = 72.92
# Iteration #37: W_new = [37.92045256  5.10734781], MSE = 70.34
# Iteration #38: W_new = [38.24620296  5.04872077], MSE = 67.99
# Iteration #39: W_new = [38.55696644  4.99203458], MSE = 65.85
# Iteration #40: W_new = [38.85365942  4.93848587], MSE = 63.9
# Iteration #41: W_new = [39.13674772  4.88696207], MSE = 62.13
# Iteration #42: W_new = [39.40698433  4.83810224], MSE = 60.51
# Iteration #43: W_new = [39.66485522  4.79123314], MSE = 59.03
# Iteration #44: W_new = [39.91099976  4.74668024], MSE = 57.69
# Iteration #45: W_new = [40.14589571  4.70402391], MSE = 56.47
# Iteration #46: W_new = [40.37009897  4.66341455], MSE = 55.35
# Iteration #47: W_new = [40.58406471  4.62458012], MSE = 54.34
# Iteration #48: W_new = [40.7882842  4.5875745], MSE = 53.42
# Iteration #49: W_new = [40.98318343  4.55221259], MSE = 52.57
# Iteration #50: W_new = [41.16920131  4.51849616], MSE = 51.81
# Iteration #51: W_new = [41.34673233  4.4862923 ], MSE = 51.11
# Iteration #52: W_new = [41.51617141  4.45557569], MSE = 50.47
# Iteration #53: W_new = [41.67788156  4.42624559], MSE = 49.89
# Iteration #54: W_new = [41.83221973  4.39826362], MSE = 49.36
# Iteration #55: W_new = [41.97951867  4.37154955], MSE = 48.88
# Iteration #56: W_new = [42.12010194  4.34605971], MSE = 48.45
# Iteration #57: W_new = [42.25427383  4.32172762], MSE = 48.05
# Iteration #58: W_new = [42.38232816  4.29850852], MSE = 47.68
# Iteration #59: W_new = [42.50454279  4.27634559], MSE = 47.35
# Iteration #60: W_new = [42.62118483  4.25519525], MSE = 47.05
# Iteration #61: W_new = [42.73250777  4.23500787], MSE = 46.78
# Iteration #62: W_new = [42.83875463  4.21574216], MSE = 46.53
# Iteration #63: W_new = [42.94015652  4.1973541 ], MSE = 46.3
# Iteration #64: W_new = [43.03693464  4.17980517], MSE = 46.09
# Iteration #65: W_new = [43.12929963  4.16305599], MSE = 45.9
# Iteration #66: W_new = [43.21745287  4.14707092], MSE = 45.73
# Iteration #67: W_new = [43.3015863   4.13181449], MSE = 45.57
# Iteration #68: W_new = [43.38188333  4.11725396], MSE = 45.43
# Iteration #69: W_new = [43.4585188   4.10335723], MSE = 45.3
# Iteration #70: W_new = [43.53165976  4.0900943 ], MSE = 45.18
# Iteration #71: W_new = [43.60146549  4.07743606], MSE = 45.07
# Iteration #72: W_new = [43.66808812  4.06535511], MSE = 44.97
# Iteration #73: W_new = [43.73167278  4.05382499], MSE = 44.88
# Iteration #74: W_new = [43.792358    4.04282068], MSE = 44.8
# Iteration #75: W_new = [43.850276    4.03231813], MSE = 44.73
# Iteration #76: W_new = [43.90555296  4.02229451], MSE = 44.66
# Iteration #77: W_new = [43.95830931  4.01272795], MSE = 44.6
# Iteration #78: W_new = [44.00866     4.00359764], MSE = 44.54
# Iteration #79: W_new = [44.0567147   3.99488365], MSE = 44.49
# Iteration #80: W_new = [44.10257814  3.98656703], MSE = 44.45
# Iteration #81: W_new = [44.14635021  3.97862964], MSE = 44.4
# Iteration #82: W_new = [44.1881263   3.97105419], MSE = 44.36
# Iteration #83: W_new = [44.22799741  3.96382418], MSE = 44.33
# Iteration #84: W_new = [44.26605042  3.95692385], MSE = 44.3
# Iteration #85: W_new = [44.30236822  3.95033818], MSE = 44.27
# Iteration #86: W_new = [44.33702995  3.94405281], MSE = 44.24
# Iteration #87: W_new = [44.37011111  3.93805405], MSE = 44.22
# Iteration #88: W_new = [44.40168378  3.93232883], MSE = 44.19
# Iteration #89: W_new = [44.43181676  3.92686468], MSE = 44.17
# Iteration #90: W_new = [44.46057568  3.9216497 ], MSE = 44.16
# Iteration #91: W_new = [44.4880232   3.91667251], MSE = 44.14
# Iteration #92: W_new = [44.51421913  3.91192228], MSE = 44.12
# Iteration #93: W_new = [44.53922053  3.90738866], MSE = 44.11
# Iteration #94: W_new = [44.56308188  3.90306178], MSE = 44.1
# Iteration #95: W_new = [44.58585516  3.89893219], MSE = 44.09
# Iteration #96: W_new = [44.60758998  3.89499092], MSE = 44.08
# Iteration #97: W_new = [44.62833371  3.89122936], MSE = 44.07
# Iteration #98: W_new = [44.64813153  3.88763933], MSE = 44.06
# Iteration #99: W_new = [44.66702658  3.88421301], MSE = 44.05
# Iteration #100: W_new = [44.68506002  3.88094292], MSE = 44.04
# Iteration #101: W_new = [44.70227114  3.87782195], MSE = 44.04
# Iteration #102: W_new = [44.71869744  3.87484329], MSE = 44.03
# Iteration #103: W_new = [44.73437471  3.87200046], MSE = 44.02
# Iteration #104: W_new = [44.7493371   3.86928726], MSE = 44.02
# Iteration #105: W_new = [44.76361721  3.86669779], MSE = 44.01
# Iteration #106: W_new = [44.77724615  3.86422639], MSE = 44.01
# Iteration #107: W_new = [44.79025362  3.86186768], MSE = 44.01
# Iteration #108: W_new = [44.80266795  3.85961654], MSE = 44.0
# Iteration #109: W_new = [44.8145162   3.85746804], MSE = 44.0
# Iteration #110: W_new = [44.82582417  3.85541751], MSE = 44.0
# Iteration #111: W_new = [44.8366165   3.85346049], MSE = 44.0
# Iteration #112: W_new = [44.8469167   3.85159271], MSE = 43.99
# Iteration #113: W_new = [44.85674722  3.84981009], MSE = 43.99
# Iteration #114: W_new = [44.86612947  3.84810877], MSE = 43.99
# Iteration #115: W_new = [44.87508389  3.84648502], MSE = 43.99
# Iteration #116: W_new = [44.88362999  3.84493532], MSE = 43.99
# Iteration #117: W_new = [44.8917864   3.84345628], MSE = 43.98
# Iteration #118: W_new = [44.89957088  3.84204468], MSE = 43.98
# Iteration #119: W_new = [44.90700038  3.84069746], MSE = 43.98
# Iteration #120: W_new = [44.91409111  3.83941166], MSE = 43.98
# Iteration #121: W_new = [44.9208585  3.8381845], MSE = 43.98
# Iteration #122: W_new = [44.9273173  3.8370133], MSE = 43.98
# Iteration #123: W_new = [44.93348158  3.8358955 ], MSE = 43.98
# Iteration #124: W_new = [44.93936477  3.83482868], MSE = 43.98
# Iteration #125: W_new = [44.94497969  3.8338105 ], MSE = 43.98
# Iteration #126: W_new = [44.95033857  3.83283875], MSE = 43.98
# Iteration #127: W_new = [44.95545309  3.83191131], MSE = 43.97
# Iteration #128: W_new = [44.96033439  3.83102616], MSE = 43.97
# Iteration #129: W_new = [44.9649931   3.83018137], MSE = 43.97

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Вместо того, чтобы задавать количество итераций, задайте другое условие останова алгоритма - когда веса перестают изменяться меньше определенного порога  𝜖

# %%
n = X.shape[1]

eta = 1e-2
eps = 1e-8

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

diff = np.Inf
W_pred = np.zeros(2)

i = 0
while diff >= eps:
    i += 1
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    W -= eta * (1/n * 2 * np.dot(y_pred - y, X))
    diff = np.linalg.norm(W_pred - W)
    W_pred = W.copy()
    eta /= 1.1
    print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 2
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #1: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #2: W_new = [5.67727273 5.88181818], MSE = 2038.48
# Iteration #3: W_new = [ 8.41919609 12.73944403], MSE = 1178.96
# Iteration #4: W_new = [9.1601782 9.5968342], MSE = 778.76
# Iteration #5: W_new = [10.42712166 10.23704211], MSE = 655.71
# Iteration #6: W_new = [11.3809656   9.90726578], MSE = 610.15
# Iteration #7: W_new = [12.25009949  9.76239834], MSE = 578.21
# Iteration #8: W_new = [13.01792287  9.62327757], MSE = 551.06
# Iteration #9: W_new = [13.69959485  9.49967703], MSE = 527.61
# Iteration #10: W_new = [14.30611272  9.38969605], MSE = 507.25
# Iteration #11: W_new = [14.84682944  9.2916458 ], MSE = 489.5
# Iteration #12: W_new = [15.32974811  9.20407606], MSE = 473.98
# Iteration #13: W_new = [15.76174853  9.12573948], MSE = 460.34
# Iteration #14: W_new = [16.14877006  9.05555911], MSE = 448.33
# Iteration #15: W_new = [16.49596054  8.99260148], MSE = 437.72
# Iteration #16: W_new = [16.80779825  8.93605452], MSE = 428.32
# Iteration #17: W_new = [17.08819246  8.88520936], MSE = 419.97
# Iteration #18: W_new = [17.34056667  8.83944518], MSE = 412.55
# Iteration #19: W_new = [17.56792792  8.79821673], MSE = 405.93
# Iteration #20: W_new = [17.77292479  8.76104371], MSE = 400.01
# Iteration #21: W_new = [17.95789609  8.72750201], MSE = 394.73
# Iteration #22: W_new = [18.12491204  8.69721625], MSE = 389.99
# Iteration #23: W_new = [18.27580915  8.66985338], MSE = 385.74
# Iteration #24: W_new = [18.41221989  8.6451174 ], MSE = 381.92
# Iteration #25: W_new = [18.53559814  8.62274465], MSE = 378.48
# Iteration #26: W_new = [18.64724093  8.60249996], MSE = 375.39
# Iteration #27: W_new = [18.74830723  8.58417314], MSE = 372.61
# Iteration #28: W_new = [18.83983414  8.56757615], MSE = 370.1
# Iteration #29: W_new = [18.92275102  8.55254045], MSE = 367.84
# Iteration #30: W_new = [18.99789165  8.53891485], MSE = 365.79
# Iteration #31: W_new = [19.06600495  8.52656356], MSE = 363.94
# Iteration #32: W_new = [19.12776431  8.51536445], MSE = 362.27
# Iteration #33: W_new = [19.18377581  8.50520763], MSE = 360.76
# Iteration #34: W_new = [19.23458538  8.4959941 ], MSE = 359.39
# Iteration #35: W_new = [19.28068521  8.4876346 ], MSE = 358.16
# Iteration #36: W_new = [19.32251934  8.48004863], MSE = 357.04
# Iteration #37: W_new = [19.36048866  8.47316348], MSE = 356.02
# Iteration #38: W_new = [19.39495531  8.46691348], MSE = 355.1
# Iteration #39: W_new = [19.42624661  8.46123929], MSE = 354.27
# Iteration #40: W_new = [19.45465856  8.45608722], MSE = 353.51
# Iteration #41: W_new = [19.48045899  8.45140871], MSE = 352.83
# Iteration #42: W_new = [19.50389029  8.4471598 ], MSE = 352.2
# Iteration #43: W_new = [19.52517196  8.4433007 ], MSE = 351.64
# Iteration #44: W_new = [19.54450282  8.43979535], MSE = 351.13
# Iteration #45: W_new = [19.56206303  8.43661107], MSE = 350.66
# Iteration #46: W_new = [19.57801587  8.43371827], MSE = 350.24
# Iteration #47: W_new = [19.59250938  8.4310901 ], MSE = 349.86
# Iteration #48: W_new = [19.60567781  8.42870221], MSE = 349.51
# Iteration #49: W_new = [19.61764292  8.42653252], MSE = 349.19
# Iteration #50: W_new = [19.62851517  8.424561  ], MSE = 348.91
# Iteration #51: W_new = [19.63839482  8.42276948], MSE = 348.65
# Iteration #52: W_new = [19.64737283  8.42114146], MSE = 348.41
# Iteration #53: W_new = [19.65553177  8.41966196], MSE = 348.19
# Iteration #54: W_new = [19.66294661  8.41831739], MSE = 348.0
# Iteration #55: W_new = [19.66968541  8.41709541], MSE = 347.82
# Iteration #56: W_new = [19.67580996  8.41598482], MSE = 347.66
# Iteration #57: W_new = [19.6813764   8.41497543], MSE = 347.51
# Iteration #58: W_new = [19.68643568  8.41405801], MSE = 347.38
# Iteration #59: W_new = [19.69103411  8.41322416], MSE = 347.26
# Iteration #60: W_new = [19.69521375  8.41246624], MSE = 347.15
# Iteration #61: W_new = [19.69901279  8.41177735], MSE = 347.05
# Iteration #62: W_new = [19.70246595  8.41115117], MSE = 346.96
# Iteration #63: W_new = [19.70560476  8.41058199], MSE = 346.88
# Iteration #64: W_new = [19.70845786  8.41006463], MSE = 346.8
# Iteration #65: W_new = [19.71105131  8.40959435], MSE = 346.73
# Iteration #66: W_new = [19.71340874  8.40916686], MSE = 346.67
# Iteration #67: W_new = [19.71555166  8.40877828], MSE = 346.62
# Iteration #68: W_new = [19.71749961  8.40842505], MSE = 346.56
# Iteration #69: W_new = [19.71927033  8.40810395], MSE = 346.52
# Iteration #70: W_new = [19.72087997  8.40781207], MSE = 346.48
# Iteration #71: W_new = [19.72234318  8.40754674], MSE = 346.44
# Iteration #72: W_new = [19.7236733   8.40730554], MSE = 346.4
# Iteration #73: W_new = [19.72488244  8.40708628], MSE = 346.37
# Iteration #74: W_new = [19.7259816   8.40688697], MSE = 346.34
# Iteration #75: W_new = [19.72698079  8.40670578], MSE = 346.32
# Iteration #76: W_new = [19.72788911  8.40654107], MSE = 346.29
# Iteration #77: W_new = [19.72871483  8.40639134], MSE = 346.27
# Iteration #78: W_new = [19.72946546  8.40625522], MSE = 346.25
# Iteration #79: W_new = [19.73014783  8.40613149], MSE = 346.23
# Iteration #80: W_new = [19.73076814  8.406019  ], MSE = 346.22
# Iteration #81: W_new = [19.73133206  8.40591674], MSE = 346.2
# Iteration #82: W_new = [19.73184469  8.40582379], MSE = 346.19
# Iteration #83: W_new = [19.73231071  8.40573928], MSE = 346.18
# Iteration #84: W_new = [19.73273436  8.40566246], MSE = 346.16
# Iteration #85: W_new = [19.73311949  8.40559262], MSE = 346.15
# Iteration #86: W_new = [19.73346961  8.40552913], MSE = 346.15
# Iteration #87: W_new = [19.73378789  8.40547142], MSE = 346.14
# Iteration #88: W_new = [19.73407723  8.40541895], MSE = 346.13
# Iteration #89: W_new = [19.73434026  8.40537125], MSE = 346.12
# Iteration #90: W_new = [19.73457938  8.40532789], MSE = 346.12
# Iteration #91: W_new = [19.73479676  8.40528847], MSE = 346.11
# Iteration #92: W_new = [19.73499438  8.40525264], MSE = 346.11
# Iteration #93: W_new = [19.73517403  8.40522006], MSE = 346.1
# Iteration #94: W_new = [19.73533734  8.40519045], MSE = 346.1
# Iteration #95: W_new = [19.73548581  8.40516352], MSE = 346.09
# Iteration #96: W_new = [19.73562078  8.40513905], MSE = 346.09
# Iteration #97: W_new = [19.73574348  8.4051168 ], MSE = 346.09
# Iteration #98: W_new = [19.73585503  8.40509657], MSE = 346.08
# Iteration #99: W_new = [19.73595643  8.40507819], MSE = 346.08
# Iteration #100: W_new = [19.73604862  8.40506147], MSE = 346.08
# Iteration #101: W_new = [19.73613242  8.40504627], MSE = 346.08
# Iteration #102: W_new = [19.73620861  8.40503246], MSE = 346.07
# Iteration #103: W_new = [19.73627787  8.4050199 ], MSE = 346.07
# Iteration #104: W_new = [19.73634083  8.40500848], MSE = 346.07
# Iteration #105: W_new = [19.73639807  8.4049981 ], MSE = 346.07
# Iteration #106: W_new = [19.73645011  8.40498867], MSE = 346.07
# Iteration #107: W_new = [19.73649741  8.40498009], MSE = 346.07
# Iteration #108: W_new = [19.73654041  8.40497229], MSE = 346.07
# Iteration #109: W_new = [19.73657951  8.4049652 ], MSE = 346.06
# Iteration #110: W_new = [19.73661505  8.40495876], MSE = 346.06
# Iteration #111: W_new = [19.73664736  8.4049529 ], MSE = 346.06
# Iteration #112: W_new = [19.73667673  8.40494757], MSE = 346.06
# Iteration #113: W_new = [19.73670343  8.40494273], MSE = 346.06
# Iteration #114: W_new = [19.73672771  8.40493833], MSE = 346.06
# Iteration #115: W_new = [19.73674978  8.40493432], MSE = 346.06
# Iteration #116: W_new = [19.73676984  8.40493069], MSE = 346.06
# Iteration #117: W_new = [19.73678808  8.40492738], MSE = 346.06
# Iteration #118: W_new = [19.73680466  8.40492437], MSE = 346.06
# Iteration #119: W_new = [19.73681973  8.40492164], MSE = 346.06
# Iteration #120: W_new = [19.73683343  8.40491916], MSE = 346.06
# Iteration #121: W_new = [19.73684589  8.4049169 ], MSE = 346.06
# Iteration #122: W_new = [19.73685721  8.40491484], MSE = 346.06
# Iteration #123: W_new = [19.73686751  8.40491298], MSE = 346.06
# Iteration #124: W_new = [19.73687686  8.40491128], MSE = 346.06
# Iteration #125: W_new = [19.73688537  8.40490974], MSE = 346.06
# Iteration #126: W_new = [19.73689311  8.40490833], MSE = 346.06
# Iteration #127: W_new = [19.73690014  8.40490706], MSE = 346.06
# Iteration #128: W_new = [19.73690653  8.4049059 ], MSE = 346.06
# Iteration #129: W_new = [19.73691234  8.40490485], MSE = 346.06
# Iteration #130: W_new = [19.73691762  8.40490389], MSE = 346.06
# Iteration #131: W_new = [19.73692243  8.40490302], MSE = 346.06
# Iteration #132: W_new = [19.73692679  8.40490223], MSE = 346.05
# Iteration #133: W_new = [19.73693076  8.40490151], MSE = 346.05
# Iteration #134: W_new = [19.73693437  8.40490085], MSE = 346.05
# Iteration #135: W_new = [19.73693765  8.40490026], MSE = 346.05
# Iteration #136: W_new = [19.73694063  8.40489972], MSE = 346.05
# Iteration #137: W_new = [19.73694334  8.40489922], MSE = 346.05
# Iteration #138: W_new = [19.73694581  8.40489878], MSE = 346.05
# Iteration #139: W_new = [19.73694805  8.40489837], MSE = 346.05
# Iteration #140: W_new = [19.73695008  8.404898  ], MSE = 346.05
# Iteration #141: W_new = [19.73695194  8.40489767], MSE = 346.05
# Iteration #142: W_new = [19.73695362  8.40489736], MSE = 346.05
# Iteration #143: W_new = [19.73695515  8.40489708], MSE = 346.05
# Iteration #144: W_new = [19.73695654  8.40489683], MSE = 346.05
# Iteration #145: W_new = [19.73695781  8.4048966 ], MSE = 346.05
# Iteration #146: W_new = [19.73695896  8.40489639], MSE = 346.05
# Iteration #147: W_new = [19.73696    8.4048962], MSE = 346.05
# Iteration #148: W_new = [19.73696095  8.40489603], MSE = 346.05
# Iteration #149: W_new = [19.73696181  8.40489587], MSE = 346.05
# Iteration #150: W_new = [19.7369626   8.40489573], MSE = 346.05
# Iteration #151: W_new = [19.73696331  8.4048956 ], MSE = 346.05
# Iteration #152: W_new = [19.73696396  8.40489549], MSE = 346.05
# Iteration #153: W_new = [19.73696455  8.40489538], MSE = 346.05
# Iteration #154: W_new = [19.73696509  8.40489528], MSE = 346.05
# Iteration #155: W_new = [19.73696558  8.40489519], MSE = 346.05
# Iteration #156: W_new = [19.73696602  8.40489511], MSE = 346.05
# Iteration #157: W_new = [19.73696642  8.40489504], MSE = 346.05
# Iteration #158: W_new = [19.73696679  8.40489497], MSE = 346.05
# Iteration #159: W_new = [19.73696712  8.40489491], MSE = 346.05
# Iteration #160: W_new = [19.73696742  8.40489486], MSE = 346.05
# Iteration #161: W_new = [19.7369677   8.40489481], MSE = 346.05
# Iteration #162: W_new = [19.73696795  8.40489476], MSE = 346.05
# Iteration #163: W_new = [19.73696818  8.40489472], MSE = 346.05
# Iteration #164: W_new = [19.73696838  8.40489468], MSE = 346.05
# Iteration #165: W_new = [19.73696857  8.40489465], MSE = 346.05
# Iteration #166: W_new = [19.73696874  8.40489462], MSE = 346.05
# Iteration #167: W_new = [19.7369689   8.40489459], MSE = 346.05
# Iteration #168: W_new = [19.73696904  8.40489456], MSE = 346.05
# Iteration #169: W_new = [19.73696917  8.40489454], MSE = 346.05
# Iteration #170: W_new = [19.73696929  8.40489452], MSE = 346.05
# Iteration #171: W_new = [19.73696939  8.4048945 ], MSE = 346.05
# Iteration #172: W_new = [19.73696949  8.40489448], MSE = 346.05
# Iteration #173: W_new = [19.73696958  8.40489447], MSE = 346.05
# Iteration #174: W_new = [19.73696966  8.40489445], MSE = 346.05
# Iteration #175: W_new = [19.73696973  8.40489444], MSE = 346.05
# Iteration #176: W_new = [19.73696979  8.40489443], MSE = 346.05
# Iteration #177: W_new = [19.73696985  8.40489442], MSE = 346.05
# Iteration #178: W_new = [19.73696991  8.40489441], MSE = 346.05
# Iteration #179: W_new = [19.73696996  8.4048944 ], MSE = 346.05
# Iteration #180: W_new = [19.73697     8.40489439], MSE = 346.05
# Iteration #181: W_new = [19.73697004  8.40489438], MSE = 346.05
# Iteration #182: W_new = [19.73697008  8.40489438], MSE = 346.05
# Iteration #183: W_new = [19.73697011  8.40489437], MSE = 346.05
# Iteration #184: W_new = [19.73697015  8.40489436], MSE = 346.05
# Iteration #185: W_new = [19.73697017  8.40489436], MSE = 346.05
# Iteration #186: W_new = [19.7369702   8.40489435], MSE = 346.05
# Iteration #187: W_new = [19.73697022  8.40489435], MSE = 346.05
# Iteration #188: W_new = [19.73697024  8.40489435], MSE = 346.05
# Iteration #189: W_new = [19.73697026  8.40489434], MSE = 346.05
# Iteration #190: W_new = [19.73697028  8.40489434], MSE = 346.05
# Iteration #191: W_new = [19.73697029  8.40489434], MSE = 346.05
# Iteration #192: W_new = [19.73697031  8.40489433], MSE = 346.05
# Iteration #193: W_new = [19.73697032  8.40489433], MSE = 346.05
# Iteration #194: W_new = [19.73697033  8.40489433], MSE = 346.05
# Iteration #195: W_new = [19.73697034  8.40489433], MSE = 346.05
# Iteration #196: W_new = [19.73697035  8.40489433], MSE = 346.05
