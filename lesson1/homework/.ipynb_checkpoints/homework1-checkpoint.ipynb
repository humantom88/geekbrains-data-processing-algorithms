# %% [markdown]
# ## Домашнее задание к уроку 1

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Подберите скорость обучения (eta) и количество итераций

# %%
import numpy as np

X = np.array([[ 1,  1],
              [ 1,  1],
              [ 1,  2],
              [ 1,  5],
              [ 1,  3],
              [ 1,  0],
              [ 1,  5],
              [ 1, 10],
              [ 1,  1],
              [ 1,  2]])

# %%
y = [45, 55, 50, 55, 60, 35, 75, 80, 50, 60]

# %%
def calc_mse(y, y_pred):
    err = np.mean((y - y_pred)**2)
    return err

# %%
n = X.shape[1]

eta = 1e-2
n_iter = 700

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    for k in range(W.shape[0]):
        W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    if i % 10 == 0:
        eta /= 1.1
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 2
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #10: W_new = [18.77319138  8.6270072 ], MSE = 398.58
# Iteration #20: W_new = [27.15289315  7.06014716], MSE = 207.1
# Iteration #30: W_new = [32.4241672   6.10426679], MSE = 124.63
# Iteration #40: W_new = [35.85213314  5.48265802], MSE = 86.53
# Iteration #50: W_new = [38.15155609  5.06569312], MSE = 67.79
# Iteration #60: W_new = [39.73790007  4.7780341 ], MSE = 58.04
# Iteration #70: W_new = [40.86051023  4.57446606], MSE = 52.69
# Iteration #80: W_new = [41.67349173  4.4270444 ], MSE = 49.62
# Iteration #90: W_new = [42.2746909  4.3180262], MSE = 47.78
# Iteration #100: W_new = [42.727794    4.23586294], MSE = 46.63
# Iteration #110: W_new = [43.07521157  4.17286412], MSE = 45.89
# Iteration #120: W_new = [43.34578807  4.12379924], MSE = 45.4
# Iteration #130: W_new = [43.55952748  4.08504089], MSE = 45.06
# Iteration #140: W_new = [43.73055537  4.05402762], MSE = 44.82
# Iteration #150: W_new = [43.8690146   4.02892018], MSE = 44.65
# Iteration #160: W_new = [43.9823022   4.00837722], MSE = 44.53
# Iteration #170: W_new = [44.0758912   3.99140629], MSE = 44.44
# Iteration #180: W_new = [44.15388587  3.97726316], MSE = 44.36
# Iteration #190: W_new = [44.21940291  3.96538266], MSE = 44.31
# Iteration #200: W_new = [44.27483692  3.95533056], MSE = 44.26
# Iteration #210: W_new = [44.32204803  3.94676955], MSE = 44.23
# Iteration #220: W_new = [44.36249605  3.93943492], MSE = 44.2
# Iteration #230: W_new = [44.39733771  3.93311693], MSE = 44.18
# Iteration #240: W_new = [44.42749793  3.92764784], MSE = 44.16
# Iteration #250: W_new = [44.45372252  3.92289241], MSE = 44.14
# Iteration #260: W_new = [44.47661773  3.91874072], MSE = 44.13
# Iteration #270: W_new = [44.49668006  3.91510272], MSE = 44.12
# Iteration #280: W_new = [44.51431902  3.91190417], MSE = 44.11
# Iteration #290: W_new = [44.5298746  3.9090834], MSE = 44.1
# Iteration #300: W_new = [44.54363088  3.90658891], MSE = 44.1
# Iteration #310: W_new = [44.55582661  3.90437741], MSE = 44.09
# Iteration #320: W_new = [44.56666354  3.9024123 ], MSE = 44.09
# Iteration #330: W_new = [44.57631309  3.9006625 ], MSE = 44.08
# Iteration #340: W_new = [44.5849216   3.89910148], MSE = 44.08
# Iteration #350: W_new = [44.59261455  3.89770648], MSE = 44.07
# Iteration #360: W_new = [44.59950005  3.8964579 ], MSE = 44.07
# Iteration #370: W_new = [44.60567159  3.89533879], MSE = 44.07
# Iteration #380: W_new = [44.61121033  3.89433442], MSE = 44.06
# Iteration #390: W_new = [44.61618698  3.89343199], MSE = 44.06
# Iteration #400: W_new = [44.62066334  3.89262027], MSE = 44.06
# Iteration #410: W_new = [44.62469361  3.89188944], MSE = 44.06
# Iteration #420: W_new = [44.62832542  3.89123087], MSE = 44.06
# Iteration #430: W_new = [44.6316008   3.89063693], MSE = 44.06
# Iteration #440: W_new = [44.63455687  3.89010089], MSE = 44.06
# Iteration #450: W_new = [44.63722652  3.88961679], MSE = 44.05
# Iteration #460: W_new = [44.63963895  3.88917933], MSE = 44.05
# Iteration #470: W_new = [44.64182013  3.88878381], MSE = 44.05
# Iteration #480: W_new = [44.64379322  3.88842602], MSE = 44.05
# Iteration #490: W_new = [44.64557886  3.88810222], MSE = 44.05
# Iteration #500: W_new = [44.64719553  3.88780906], MSE = 44.05
# Iteration #510: W_new = [44.64865977  3.88754355], MSE = 44.05
# Iteration #520: W_new = [44.64998639  3.88730298], MSE = 44.05
# Iteration #530: W_new = [44.6511887   3.88708496], MSE = 44.05
# Iteration #540: W_new = [44.65227866  3.88688732], MSE = 44.05
# Iteration #550: W_new = [44.653267    3.88670809], MSE = 44.05
# Iteration #560: W_new = [44.65416343  3.88654554], MSE = 44.05
# Iteration #570: W_new = [44.65497665  3.88639808], MSE = 44.05
# Iteration #580: W_new = [44.65571452  3.88626427], MSE = 44.05
# Iteration #590: W_new = [44.65638416  3.88614285], MSE = 44.05
# Iteration #600: W_new = [44.65699195  3.88603263], MSE = 44.05
# Iteration #610: W_new = [44.6575437   3.88593258], MSE = 44.05
# Iteration #620: W_new = [44.65804463  3.88584174], MSE = 44.05
# Iteration #630: W_new = [44.65849949  3.88575926], MSE = 44.05
# Iteration #640: W_new = [44.65891255  3.88568436], MSE = 44.05
# Iteration #650: W_new = [44.65928769  3.88561634], MSE = 44.05
# Iteration #660: W_new = [44.65962842  3.88555455], MSE = 44.05
# Iteration #670: W_new = [44.65993792  3.88549843], MSE = 44.05
# Iteration #680: W_new = [44.66021908  3.88544744], MSE = 44.04
# Iteration #690: W_new = [44.66047451  3.88540112], MSE = 44.04

# %% [markdown]
# ## Задание 2

# %% [markdown]
# В этом коде мы избавляемся от итераций по весам, но тут есть ошибка, исправьте ее

# %%
n = X.shape[1]

eta = 1e-2
n_iter = 130

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
#     for k in range(W.shape[0]):
#         W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    # ИЗМЕНЕНИЯ
    W -= eta * (1/n * 2 * np.dot(y_pred - y, X))
    print(f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')
# Out:
# Number of objects = 2
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #1: W_new = [5.605 4.535], MSE = 2038.48
# Iteration #2: W_new = [ 9.334 15.144], MSE = 1438.69
# Iteration #3: W_new = [9.5074 6.599 ], MSE = 1074.2
# Iteration #4: W_new = [12.22696 12.52848], MSE = 845.69
# Iteration #5: W_new = [12.89572   7.561976], MSE = 696.44
# Iteration #6: W_new = [14.9875552 10.8379008], MSE = 594.01
# Iteration #7: W_new = [15.88742944  7.91720288], MSE = 519.8
# Iteration #8: W_new = [17.57352563  9.69172915], MSE = 463.05
# Iteration #9: W_new = [18.55865432  7.9437319 ], MSE = 417.54
# Iteration #10: W_new = [19.96966932  8.87179137], MSE = 379.6
# Iteration #11: W_new = [20.96116498  7.79884524], MSE = 347.05
# Iteration #12: W_new = [22.17539491  8.25245884], MSE = 318.53
# Iteration #13: W_new = [23.13211776  7.57066034], MSE = 293.21
# Iteration #14: W_new = [24.19770788  7.76090243], MSE = 270.51
# Iteration #15: W_new = [25.09966637  7.30805593], MSE = 250.04
# Iteration #16: W_new = [26.04728295  7.35446094], MSE = 231.52
# Iteration #17: W_new = [26.88621637  7.03769246], MSE = 214.71
# Iteration #18: W_new = [27.736287    7.00775037], MSE = 199.45
# Iteration #19: W_new = [28.51033319  6.77368864], MSE = 185.56
# Iteration #20: W_new = [29.27719328  6.70531799], MSE = 172.93
# Iteration #21: W_new = [29.98787855  6.52311942], MSE = 161.42
# Iteration #22: W_new = [30.68215487  6.43745284], MSE = 150.95
# Iteration #23: W_new = [31.33270353  6.28913655], MSE = 141.41
# Iteration #24: W_new = [31.96269221  6.19779335], MSE = 132.73
# Iteration #25: W_new = [32.55708499  6.07273699], MSE = 124.82
# Iteration #26: W_new = [33.12955539  5.98195861], MSE = 117.61
# Iteration #27: W_new = [33.67201227  5.87376235], MSE = 111.05
# Iteration #28: W_new = [34.19268233  5.78676267], MSE = 105.07
# Iteration #29: W_new = [34.6873853   5.69146143], MSE = 99.62
# Iteration #30: W_new = [35.16120834  5.60976141], MSE = 94.66
# Iteration #31: W_new = [35.61215908  5.52480451], MSE = 90.15
# Iteration #32: W_new = [36.04350182  5.44898912], MSE = 86.03
# Iteration #33: W_new = [36.4544549   5.37265707], MSE = 82.28
# Iteration #34: W_new = [36.84721229  5.30280358], MSE = 78.87
# Iteration #35: W_new = [37.22164999  5.23387381], MSE = 75.76
# Iteration #36: W_new = [37.57932285  5.16979334], MSE = 72.92
# Iteration #37: W_new = [37.92045256  5.10734781], MSE = 70.34
# Iteration #38: W_new = [38.24620296  5.04872077], MSE = 67.99
# Iteration #39: W_new = [38.55696644  4.99203458], MSE = 65.85
# Iteration #40: W_new = [38.85365942  4.93848587], MSE = 63.9
# Iteration #41: W_new = [39.13674772  4.88696207], MSE = 62.13
# Iteration #42: W_new = [39.40698433  4.83810224], MSE = 60.51
# Iteration #43: W_new = [39.66485522  4.79123314], MSE = 59.03
# Iteration #44: W_new = [39.91099976  4.74668024], MSE = 57.69
# Iteration #45: W_new = [40.14589571  4.70402391], MSE = 56.47
# Iteration #46: W_new = [40.37009897  4.66341455], MSE = 55.35
# Iteration #47: W_new = [40.58406471  4.62458012], MSE = 54.34
# Iteration #48: W_new = [40.7882842  4.5875745], MSE = 53.42
# Iteration #49: W_new = [40.98318343  4.55221259], MSE = 52.57
# Iteration #50: W_new = [41.16920131  4.51849616], MSE = 51.81
# Iteration #51: W_new = [41.34673233  4.4862923 ], MSE = 51.11
# Iteration #52: W_new = [41.51617141  4.45557569], MSE = 50.47
# Iteration #53: W_new = [41.67788156  4.42624559], MSE = 49.89
# Iteration #54: W_new = [41.83221973  4.39826362], MSE = 49.36
# Iteration #55: W_new = [41.97951867  4.37154955], MSE = 48.88
# Iteration #56: W_new = [42.12010194  4.34605971], MSE = 48.45
# Iteration #57: W_new = [42.25427383  4.32172762], MSE = 48.05
# Iteration #58: W_new = [42.38232816  4.29850852], MSE = 47.68
# Iteration #59: W_new = [42.50454279  4.27634559], MSE = 47.35
# Iteration #60: W_new = [42.62118483  4.25519525], MSE = 47.05
# Iteration #61: W_new = [42.73250777  4.23500787], MSE = 46.78
# Iteration #62: W_new = [42.83875463  4.21574216], MSE = 46.53
# Iteration #63: W_new = [42.94015652  4.1973541 ], MSE = 46.3
# Iteration #64: W_new = [43.03693464  4.17980517], MSE = 46.09
# Iteration #65: W_new = [43.12929963  4.16305599], MSE = 45.9
# Iteration #66: W_new = [43.21745287  4.14707092], MSE = 45.73
# Iteration #67: W_new = [43.3015863   4.13181449], MSE = 45.57
# Iteration #68: W_new = [43.38188333  4.11725396], MSE = 45.43
# Iteration #69: W_new = [43.4585188   4.10335723], MSE = 45.3
# Iteration #70: W_new = [43.53165976  4.0900943 ], MSE = 45.18
# Iteration #71: W_new = [43.60146549  4.07743606], MSE = 45.07
# Iteration #72: W_new = [43.66808812  4.06535511], MSE = 44.97
# Iteration #73: W_new = [43.73167278  4.05382499], MSE = 44.88
# Iteration #74: W_new = [43.792358    4.04282068], MSE = 44.8
# Iteration #75: W_new = [43.850276    4.03231813], MSE = 44.73
# Iteration #76: W_new = [43.90555296  4.02229451], MSE = 44.66
# Iteration #77: W_new = [43.95830931  4.01272795], MSE = 44.6
# Iteration #78: W_new = [44.00866     4.00359764], MSE = 44.54
# Iteration #79: W_new = [44.0567147   3.99488365], MSE = 44.49
# Iteration #80: W_new = [44.10257814  3.98656703], MSE = 44.45
# Iteration #81: W_new = [44.14635021  3.97862964], MSE = 44.4
# Iteration #82: W_new = [44.1881263   3.97105419], MSE = 44.36
# Iteration #83: W_new = [44.22799741  3.96382418], MSE = 44.33
# Iteration #84: W_new = [44.26605042  3.95692385], MSE = 44.3
# Iteration #85: W_new = [44.30236822  3.95033818], MSE = 44.27
# Iteration #86: W_new = [44.33702995  3.94405281], MSE = 44.24
# Iteration #87: W_new = [44.37011111  3.93805405], MSE = 44.22
# Iteration #88: W_new = [44.40168378  3.93232883], MSE = 44.19
# Iteration #89: W_new = [44.43181676  3.92686468], MSE = 44.17
# Iteration #90: W_new = [44.46057568  3.9216497 ], MSE = 44.16
# Iteration #91: W_new = [44.4880232   3.91667251], MSE = 44.14
# Iteration #92: W_new = [44.51421913  3.91192228], MSE = 44.12
# Iteration #93: W_new = [44.53922053  3.90738866], MSE = 44.11
# Iteration #94: W_new = [44.56308188  3.90306178], MSE = 44.1
# Iteration #95: W_new = [44.58585516  3.89893219], MSE = 44.09
# Iteration #96: W_new = [44.60758998  3.89499092], MSE = 44.08
# Iteration #97: W_new = [44.62833371  3.89122936], MSE = 44.07
# Iteration #98: W_new = [44.64813153  3.88763933], MSE = 44.06
# Iteration #99: W_new = [44.66702658  3.88421301], MSE = 44.05
# Iteration #100: W_new = [44.68506002  3.88094292], MSE = 44.04
# Iteration #101: W_new = [44.70227114  3.87782195], MSE = 44.04
# Iteration #102: W_new = [44.71869744  3.87484329], MSE = 44.03
# Iteration #103: W_new = [44.73437471  3.87200046], MSE = 44.02
# Iteration #104: W_new = [44.7493371   3.86928726], MSE = 44.02
# Iteration #105: W_new = [44.76361721  3.86669779], MSE = 44.01
# Iteration #106: W_new = [44.77724615  3.86422639], MSE = 44.01
# Iteration #107: W_new = [44.79025362  3.86186768], MSE = 44.01
# Iteration #108: W_new = [44.80266795  3.85961654], MSE = 44.0
# Iteration #109: W_new = [44.8145162   3.85746804], MSE = 44.0
# Iteration #110: W_new = [44.82582417  3.85541751], MSE = 44.0
# Iteration #111: W_new = [44.8366165   3.85346049], MSE = 44.0
# Iteration #112: W_new = [44.8469167   3.85159271], MSE = 43.99
# Iteration #113: W_new = [44.85674722  3.84981009], MSE = 43.99
# Iteration #114: W_new = [44.86612947  3.84810877], MSE = 43.99
# Iteration #115: W_new = [44.87508389  3.84648502], MSE = 43.99
# Iteration #116: W_new = [44.88362999  3.84493532], MSE = 43.99
# Iteration #117: W_new = [44.8917864   3.84345628], MSE = 43.98
# Iteration #118: W_new = [44.89957088  3.84204468], MSE = 43.98
# Iteration #119: W_new = [44.90700038  3.84069746], MSE = 43.98
# Iteration #120: W_new = [44.91409111  3.83941166], MSE = 43.98
# Iteration #121: W_new = [44.9208585  3.8381845], MSE = 43.98
# Iteration #122: W_new = [44.9273173  3.8370133], MSE = 43.98
# Iteration #123: W_new = [44.93348158  3.8358955 ], MSE = 43.98
# Iteration #124: W_new = [44.93936477  3.83482868], MSE = 43.98
# Iteration #125: W_new = [44.94497969  3.8338105 ], MSE = 43.98
# Iteration #126: W_new = [44.95033857  3.83283875], MSE = 43.98
# Iteration #127: W_new = [44.95545309  3.83191131], MSE = 43.97
# Iteration #128: W_new = [44.96033439  3.83102616], MSE = 43.97
# Iteration #129: W_new = [44.9649931   3.83018137], MSE = 43.97

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Вместо того, чтобы задавать количество итераций, задайте другое условие останова алгоритма - когда веса перестают изменяться меньше определенного порога  𝜖

# %%
n = X.shape[1]

eta = 1e-2
eps = 1e-7

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

W_pred = W.copy()

diff = np.inf

i = 0

while diff >= eps:
    i += 1
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    
    W -= eta * (1/n * 2 * np.dot(y_pred - y, X))
    
    print(f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')
    
    diff = np.linalg.norm(W - W_pred, ord=2)
    
    W_pred = W.copy()
# Out:
# Number of objects = 2
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #1: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #2: W_new = [5.605 4.535], MSE = 2038.48
# Iteration #3: W_new = [ 9.334 15.144], MSE = 1438.69
# Iteration #4: W_new = [9.5074 6.599 ], MSE = 1074.2
# Iteration #5: W_new = [12.22696 12.52848], MSE = 845.69
# Iteration #6: W_new = [12.89572   7.561976], MSE = 696.44
# Iteration #7: W_new = [14.9875552 10.8379008], MSE = 594.01
# Iteration #8: W_new = [15.88742944  7.91720288], MSE = 519.8
# Iteration #9: W_new = [17.57352563  9.69172915], MSE = 463.05
# Iteration #10: W_new = [18.55865432  7.9437319 ], MSE = 417.54
# Iteration #11: W_new = [19.96966932  8.87179137], MSE = 379.6
# Iteration #12: W_new = [20.96116498  7.79884524], MSE = 347.05
# Iteration #13: W_new = [22.17539491  8.25245884], MSE = 318.53
# Iteration #14: W_new = [23.13211776  7.57066034], MSE = 293.21
# Iteration #15: W_new = [24.19770788  7.76090243], MSE = 270.51
# Iteration #16: W_new = [25.09966637  7.30805593], MSE = 250.04
# Iteration #17: W_new = [26.04728295  7.35446094], MSE = 231.52
# Iteration #18: W_new = [26.88621637  7.03769246], MSE = 214.71
# Iteration #19: W_new = [27.736287    7.00775037], MSE = 199.45
# Iteration #20: W_new = [28.51033319  6.77368864], MSE = 185.56
# Iteration #21: W_new = [29.27719328  6.70531799], MSE = 172.93
# Iteration #22: W_new = [29.98787855  6.52311942], MSE = 161.42
# Iteration #23: W_new = [30.68215487  6.43745284], MSE = 150.95
# Iteration #24: W_new = [31.33270353  6.28913655], MSE = 141.41
# Iteration #25: W_new = [31.96269221  6.19779335], MSE = 132.73
# Iteration #26: W_new = [32.55708499  6.07273699], MSE = 124.82
# Iteration #27: W_new = [33.12955539  5.98195861], MSE = 117.61
# Iteration #28: W_new = [33.67201227  5.87376235], MSE = 111.05
# Iteration #29: W_new = [34.19268233  5.78676267], MSE = 105.07
# Iteration #30: W_new = [34.6873853   5.69146143], MSE = 99.62
# Iteration #31: W_new = [35.16120834  5.60976141], MSE = 94.66
# Iteration #32: W_new = [35.61215908  5.52480451], MSE = 90.15
# Iteration #33: W_new = [36.04350182  5.44898912], MSE = 86.03
# Iteration #34: W_new = [36.4544549   5.37265707], MSE = 82.28
# Iteration #35: W_new = [36.84721229  5.30280358], MSE = 78.87
# Iteration #36: W_new = [37.22164999  5.23387381], MSE = 75.76
# Iteration #37: W_new = [37.57932285  5.16979334], MSE = 72.92
# Iteration #38: W_new = [37.92045256  5.10734781], MSE = 70.34
# Iteration #39: W_new = [38.24620296  5.04872077], MSE = 67.99
# Iteration #40: W_new = [38.55696644  4.99203458], MSE = 65.85
# Iteration #41: W_new = [38.85365942  4.93848587], MSE = 63.9
# Iteration #42: W_new = [39.13674772  4.88696207], MSE = 62.13
# Iteration #43: W_new = [39.40698433  4.83810224], MSE = 60.51
# Iteration #44: W_new = [39.66485522  4.79123314], MSE = 59.03
# Iteration #45: W_new = [39.91099976  4.74668024], MSE = 57.69
# Iteration #46: W_new = [40.14589571  4.70402391], MSE = 56.47
# Iteration #47: W_new = [40.37009897  4.66341455], MSE = 55.35
# Iteration #48: W_new = [40.58406471  4.62458012], MSE = 54.34
# Iteration #49: W_new = [40.7882842  4.5875745], MSE = 53.42
# Iteration #50: W_new = [40.98318343  4.55221259], MSE = 52.57
# Iteration #51: W_new = [41.16920131  4.51849616], MSE = 51.81
# Iteration #52: W_new = [41.34673233  4.4862923 ], MSE = 51.11
# Iteration #53: W_new = [41.51617141  4.45557569], MSE = 50.47
# Iteration #54: W_new = [41.67788156  4.42624559], MSE = 49.89
# Iteration #55: W_new = [41.83221973  4.39826362], MSE = 49.36
# Iteration #56: W_new = [41.97951867  4.37154955], MSE = 48.88
# Iteration #57: W_new = [42.12010194  4.34605971], MSE = 48.45
# Iteration #58: W_new = [42.25427383  4.32172762], MSE = 48.05
# Iteration #59: W_new = [42.38232816  4.29850852], MSE = 47.68
# Iteration #60: W_new = [42.50454279  4.27634559], MSE = 47.35
# Iteration #61: W_new = [42.62118483  4.25519525], MSE = 47.05
# Iteration #62: W_new = [42.73250777  4.23500787], MSE = 46.78
# Iteration #63: W_new = [42.83875463  4.21574216], MSE = 46.53
# Iteration #64: W_new = [42.94015652  4.1973541 ], MSE = 46.3
# Iteration #65: W_new = [43.03693464  4.17980517], MSE = 46.09
# Iteration #66: W_new = [43.12929963  4.16305599], MSE = 45.9
# Iteration #67: W_new = [43.21745287  4.14707092], MSE = 45.73
# Iteration #68: W_new = [43.3015863   4.13181449], MSE = 45.57
# Iteration #69: W_new = [43.38188333  4.11725396], MSE = 45.43
# Iteration #70: W_new = [43.4585188   4.10335723], MSE = 45.3
# Iteration #71: W_new = [43.53165976  4.0900943 ], MSE = 45.18
# Iteration #72: W_new = [43.60146549  4.07743606], MSE = 45.07
# Iteration #73: W_new = [43.66808812  4.06535511], MSE = 44.97
# Iteration #74: W_new = [43.73167278  4.05382499], MSE = 44.88
# Iteration #75: W_new = [43.792358    4.04282068], MSE = 44.8
# Iteration #76: W_new = [43.850276    4.03231813], MSE = 44.73
# Iteration #77: W_new = [43.90555296  4.02229451], MSE = 44.66
# Iteration #78: W_new = [43.95830931  4.01272795], MSE = 44.6
# Iteration #79: W_new = [44.00866     4.00359764], MSE = 44.54
# Iteration #80: W_new = [44.0567147   3.99488365], MSE = 44.49
# Iteration #81: W_new = [44.10257814  3.98656703], MSE = 44.45
# Iteration #82: W_new = [44.14635021  3.97862964], MSE = 44.4
# Iteration #83: W_new = [44.1881263   3.97105419], MSE = 44.36
# Iteration #84: W_new = [44.22799741  3.96382418], MSE = 44.33
# Iteration #85: W_new = [44.26605042  3.95692385], MSE = 44.3
# Iteration #86: W_new = [44.30236822  3.95033818], MSE = 44.27
# Iteration #87: W_new = [44.33702995  3.94405281], MSE = 44.24
# Iteration #88: W_new = [44.37011111  3.93805405], MSE = 44.22
# Iteration #89: W_new = [44.40168378  3.93232883], MSE = 44.19
# Iteration #90: W_new = [44.43181676  3.92686468], MSE = 44.17
# Iteration #91: W_new = [44.46057568  3.9216497 ], MSE = 44.16
# Iteration #92: W_new = [44.4880232   3.91667251], MSE = 44.14
# Iteration #93: W_new = [44.51421913  3.91192228], MSE = 44.12
# Iteration #94: W_new = [44.53922053  3.90738866], MSE = 44.11
# Iteration #95: W_new = [44.56308188  3.90306178], MSE = 44.1
# Iteration #96: W_new = [44.58585516  3.89893219], MSE = 44.09
# Iteration #97: W_new = [44.60758998  3.89499092], MSE = 44.08
# Iteration #98: W_new = [44.62833371  3.89122936], MSE = 44.07
# Iteration #99: W_new = [44.64813153  3.88763933], MSE = 44.06
# Iteration #100: W_new = [44.66702658  3.88421301], MSE = 44.05
# Iteration #101: W_new = [44.68506002  3.88094292], MSE = 44.04
# Iteration #102: W_new = [44.70227114  3.87782195], MSE = 44.04
# Iteration #103: W_new = [44.71869744  3.87484329], MSE = 44.03
# Iteration #104: W_new = [44.73437471  3.87200046], MSE = 44.02
# Iteration #105: W_new = [44.7493371   3.86928726], MSE = 44.02
# Iteration #106: W_new = [44.76361721  3.86669779], MSE = 44.01
# Iteration #107: W_new = [44.77724615  3.86422639], MSE = 44.01
# Iteration #108: W_new = [44.79025362  3.86186768], MSE = 44.01
# Iteration #109: W_new = [44.80266795  3.85961654], MSE = 44.0
# Iteration #110: W_new = [44.8145162   3.85746804], MSE = 44.0
# Iteration #111: W_new = [44.82582417  3.85541751], MSE = 44.0
# Iteration #112: W_new = [44.8366165   3.85346049], MSE = 44.0
# Iteration #113: W_new = [44.8469167   3.85159271], MSE = 43.99
# Iteration #114: W_new = [44.85674722  3.84981009], MSE = 43.99
# Iteration #115: W_new = [44.86612947  3.84810877], MSE = 43.99
# Iteration #116: W_new = [44.87508389  3.84648502], MSE = 43.99
# Iteration #117: W_new = [44.88362999  3.84493532], MSE = 43.99
# Iteration #118: W_new = [44.8917864   3.84345628], MSE = 43.98
# Iteration #119: W_new = [44.89957088  3.84204468], MSE = 43.98
# Iteration #120: W_new = [44.90700038  3.84069746], MSE = 43.98
# Iteration #121: W_new = [44.91409111  3.83941166], MSE = 43.98
# Iteration #122: W_new = [44.9208585  3.8381845], MSE = 43.98
# Iteration #123: W_new = [44.9273173  3.8370133], MSE = 43.98
# Iteration #124: W_new = [44.93348158  3.8358955 ], MSE = 43.98
# Iteration #125: W_new = [44.93936477  3.83482868], MSE = 43.98
# Iteration #126: W_new = [44.94497969  3.8338105 ], MSE = 43.98
# Iteration #127: W_new = [44.95033857  3.83283875], MSE = 43.98
# Iteration #128: W_new = [44.95545309  3.83191131], MSE = 43.97
# Iteration #129: W_new = [44.96033439  3.83102616], MSE = 43.97
# Iteration #130: W_new = [44.9649931   3.83018137], MSE = 43.97
# Iteration #131: W_new = [44.96943938  3.82937511], MSE = 43.97
# Iteration #132: W_new = [44.97368291  3.82860561], MSE = 43.97
# Iteration #133: W_new = [44.97773294  3.8278712 ], MSE = 43.97
# Iteration #134: W_new = [44.98159828  3.82717028], MSE = 43.97
# Iteration #135: W_new = [44.98528737  3.82650132], MSE = 43.97
# Iteration #136: W_new = [44.98880824  3.82586286], MSE = 43.97
# Iteration #137: W_new = [44.99216855  3.82525352], MSE = 43.97
# Iteration #138: W_new = [44.99537564  3.82467197], MSE = 43.97
# Iteration #139: W_new = [44.99843649  3.82411693], MSE = 43.97
# Iteration #140: W_new = [45.00135776  3.8235872 ], MSE = 43.97
# Iteration #141: W_new = [45.00414582  3.82308163], MSE = 43.97
# Iteration #142: W_new = [45.00680675  3.82259911], MSE = 43.97
# Iteration #143: W_new = [45.00934634  3.8221386 ], MSE = 43.97
# Iteration #144: W_new = [45.01177013  3.82169908], MSE = 43.97
# Iteration #145: W_new = [45.01408339  3.82127961], MSE = 43.97
# Iteration #146: W_new = [45.01629117  3.82087926], MSE = 43.97
# Iteration #147: W_new = [45.01839828  3.82049717], MSE = 43.97
# Iteration #148: W_new = [45.0204093  3.8201325], MSE = 43.97
# Iteration #149: W_new = [45.02232862  3.81978446], MSE = 43.97
# Iteration #150: W_new = [45.02416042  3.81945229], MSE = 43.97
# Iteration #151: W_new = [45.02590869  3.81913527], MSE = 43.97
# Iteration #152: W_new = [45.02757724  3.8188327 ], MSE = 43.97
# Iteration #153: W_new = [45.0291697   3.81854394], MSE = 43.97
# Iteration #154: W_new = [45.03068955  3.81826833], MSE = 43.97
# Iteration #155: W_new = [45.0321401  3.8180053], MSE = 43.97
# Iteration #156: W_new = [45.0335245   3.81775426], MSE = 43.97
# Iteration #157: W_new = [45.03484577  3.81751467], MSE = 43.97
# Iteration #158: W_new = [45.03610679  3.817286  ], MSE = 43.97
# Iteration #159: W_new = [45.03731031  3.81706776], MSE = 43.97
# Iteration #160: W_new = [45.03845895  3.81685947], MSE = 43.97
# Iteration #161: W_new = [45.03955522  3.81666068], MSE = 43.97
# Iteration #162: W_new = [45.04060149  3.81647096], MSE = 43.97
# Iteration #163: W_new = [45.04160005  3.81628988], MSE = 43.97
# Iteration #164: W_new = [45.04255308  3.81611707], MSE = 43.97
# Iteration #165: W_new = [45.04346266  3.81595213], MSE = 43.97
# Iteration #166: W_new = [45.04433075  3.81579471], MSE = 43.97
# Iteration #167: W_new = [45.04515926  3.81564448], MSE = 43.97
# Iteration #168: W_new = [45.04594999  3.81550109], MSE = 43.97
# Iteration #169: W_new = [45.04670467  3.81536424], MSE = 43.97
# Iteration #170: W_new = [45.04742493  3.81523363], MSE = 43.97
# Iteration #171: W_new = [45.04811235  3.81510898], MSE = 43.97
# Iteration #172: W_new = [45.04876842  3.81499001], MSE = 43.97
# Iteration #173: W_new = [45.04939457  3.81487647], MSE = 43.97
# Iteration #174: W_new = [45.04999218  3.8147681 ], MSE = 43.97
# Iteration #175: W_new = [45.05056253  3.81466468], MSE = 43.97
# Iteration #176: W_new = [45.05110687  3.81456597], MSE = 43.97
# Iteration #177: W_new = [45.05162639  3.81447176], MSE = 43.97
# Iteration #178: W_new = [45.05212223  3.81438185], MSE = 43.97
# Iteration #179: W_new = [45.05259545  3.81429604], MSE = 43.97
# Iteration #180: W_new = [45.05304709  3.81421414], MSE = 43.97
# Iteration #181: W_new = [45.05347814  3.81413597], MSE = 43.97
# Iteration #182: W_new = [45.05388954  3.81406138], MSE = 43.97
# Iteration #183: W_new = [45.05428217  3.81399018], MSE = 43.97
# Iteration #184: W_new = [45.0546569   3.81392223], MSE = 43.97
# Iteration #185: W_new = [45.05501454  3.81385737], MSE = 43.97
# Iteration #186: W_new = [45.05535588  3.81379548], MSE = 43.97
# Iteration #187: W_new = [45.05568165  3.8137364 ], MSE = 43.97
# Iteration #188: W_new = [45.05599256  3.81368002], MSE = 43.97
# Iteration #189: W_new = [45.0562893   3.81362622], MSE = 43.97
# Iteration #190: W_new = [45.0565725   3.81357486], MSE = 43.97
# Iteration #191: W_new = [45.05684279  3.81352585], MSE = 43.97
# Iteration #192: W_new = [45.05710076  3.81347907], MSE = 43.97
# Iteration #193: W_new = [45.05734696  3.81343442], MSE = 43.97
# Iteration #194: W_new = [45.05758194  3.81339181], MSE = 43.97
# Iteration #195: W_new = [45.0578062   3.81335115], MSE = 43.97
# Iteration #196: W_new = [45.05802024  3.81331234], MSE = 43.97
# Iteration #197: W_new = [45.05822451  3.81327529], MSE = 43.97
# Iteration #198: W_new = [45.05841947  3.81323994], MSE = 43.97
# Iteration #199: W_new = [45.05860554  3.8132062 ], MSE = 43.97
# Iteration #200: W_new = [45.05878313  3.813174  ], MSE = 43.97
# Iteration #201: W_new = [45.05895262  3.81314326], MSE = 43.97
# Iteration #202: W_new = [45.05911438  3.81311393], MSE = 43.97
# Iteration #203: W_new = [45.05926876  3.81308594], MSE = 43.97
# Iteration #204: W_new = [45.0594161   3.81305922], MSE = 43.97
# Iteration #205: W_new = [45.05955673  3.81303372], MSE = 43.97
# Iteration #206: W_new = [45.05969094  3.81300938], MSE = 43.97
# Iteration #207: W_new = [45.05981903  3.81298615], MSE = 43.97
# Iteration #208: W_new = [45.05994128  3.81296398], MSE = 43.97
# Iteration #209: W_new = [45.06005796  3.81294283], MSE = 43.97
# Iteration #210: W_new = [45.06016932  3.81292263], MSE = 43.97
# Iteration #211: W_new = [45.06027559  3.81290336], MSE = 43.97
# Iteration #212: W_new = [45.06037703  3.81288497], MSE = 43.97
# Iteration #213: W_new = [45.06047383  3.81286741], MSE = 43.97
# Iteration #214: W_new = [45.06056623  3.81285066], MSE = 43.97
# Iteration #215: W_new = [45.0606544   3.81283467], MSE = 43.97
# Iteration #216: W_new = [45.06073856  3.81281941], MSE = 43.97
# Iteration #217: W_new = [45.06081888  3.81280484], MSE = 43.97
# Iteration #218: W_new = [45.06089554  3.81279094], MSE = 43.97
# Iteration #219: W_new = [45.06096871  3.81277768], MSE = 43.97
# Iteration #220: W_new = [45.06103853  3.81276501], MSE = 43.97
# Iteration #221: W_new = [45.06110517  3.81275293], MSE = 43.97
# Iteration #222: W_new = [45.06116878  3.8127414 ], MSE = 43.97
# Iteration #223: W_new = [45.06122948  3.81273039], MSE = 43.97
# Iteration #224: W_new = [45.06128742  3.81271988], MSE = 43.97
# Iteration #225: W_new = [45.06134271  3.81270986], MSE = 43.97
# Iteration #226: W_new = [45.06139548  3.81270029], MSE = 43.97
# Iteration #227: W_new = [45.06144585  3.81269115], MSE = 43.97
# Iteration #228: W_new = [45.06149392  3.81268244], MSE = 43.97
# Iteration #229: W_new = [45.06153979  3.81267412], MSE = 43.97
# Iteration #230: W_new = [45.06158358  3.81266618], MSE = 43.97
# Iteration #231: W_new = [45.06162537  3.8126586 ], MSE = 43.97
# Iteration #232: W_new = [45.06166525  3.81265137], MSE = 43.97
# Iteration #233: W_new = [45.06170331  3.81264447], MSE = 43.97
# Iteration #234: W_new = [45.06173964  3.81263788], MSE = 43.97
# Iteration #235: W_new = [45.06177431  3.81263159], MSE = 43.97
# Iteration #236: W_new = [45.06180741  3.81262559], MSE = 43.97
# Iteration #237: W_new = [45.06183899  3.81261986], MSE = 43.97
# Iteration #238: W_new = [45.06186913  3.8126144 ], MSE = 43.97
# Iteration #239: W_new = [45.0618979   3.81260918], MSE = 43.97
# Iteration #240: W_new = [45.06192535  3.8126042 ], MSE = 43.97
# Iteration #241: W_new = [45.06195156  3.81259945], MSE = 43.97
# Iteration #242: W_new = [45.06197657  3.81259492], MSE = 43.97
# Iteration #243: W_new = [45.06200043  3.81259059], MSE = 43.97
# Iteration #244: W_new = [45.06202321  3.81258646], MSE = 43.97
# Iteration #245: W_new = [45.06204495  3.81258252], MSE = 43.97
# Iteration #246: W_new = [45.0620657   3.81257875], MSE = 43.97
# Iteration #247: W_new = [45.06208551  3.81257516], MSE = 43.97
# Iteration #248: W_new = [45.06210441  3.81257173], MSE = 43.97
# Iteration #249: W_new = [45.06212245  3.81256846], MSE = 43.97
# Iteration #250: W_new = [45.06213966  3.81256534], MSE = 43.97
# Iteration #251: W_new = [45.0621561   3.81256236], MSE = 43.97
# Iteration #252: W_new = [45.06217178  3.81255952], MSE = 43.97
# Iteration #253: W_new = [45.06218674  3.8125568 ], MSE = 43.97
# Iteration #254: W_new = [45.06220103  3.81255421], MSE = 43.97
# Iteration #255: W_new = [45.06221466  3.81255174], MSE = 43.97
# Iteration #256: W_new = [45.06222767  3.81254938], MSE = 43.97
# Iteration #257: W_new = [45.06224009  3.81254713], MSE = 43.97
# Iteration #258: W_new = [45.06225194  3.81254498], MSE = 43.97
# Iteration #259: W_new = [45.06226325  3.81254293], MSE = 43.97
# Iteration #260: W_new = [45.06227405  3.81254097], MSE = 43.97
# Iteration #261: W_new = [45.06228435  3.8125391 ], MSE = 43.97
# Iteration #262: W_new = [45.06229419  3.81253732], MSE = 43.97
# Iteration #263: W_new = [45.06230357  3.81253562], MSE = 43.97
# Iteration #264: W_new = [45.06231253  3.812534  ], MSE = 43.97
# Iteration #265: W_new = [45.06232108  3.81253244], MSE = 43.97
# Iteration #266: W_new = [45.06232924  3.81253097], MSE = 43.97
# Iteration #267: W_new = [45.06233702  3.81252955], MSE = 43.97
# Iteration #268: W_new = [45.06234445  3.81252821], MSE = 43.97
# Iteration #269: W_new = [45.06235155  3.81252692], MSE = 43.97
# Iteration #270: W_new = [45.06235832  3.81252569], MSE = 43.97
# Iteration #271: W_new = [45.06236478  3.81252452], MSE = 43.97
# Iteration #272: W_new = [45.06237094  3.8125234 ], MSE = 43.97
# Iteration #273: W_new = [45.06237683  3.81252234], MSE = 43.97
# Iteration #274: W_new = [45.06238244  3.81252132], MSE = 43.97
# Iteration #275: W_new = [45.06238781  3.81252034], MSE = 43.97
# Iteration #276: W_new = [45.06239292  3.81251942], MSE = 43.97
# Iteration #277: W_new = [45.0623978   3.81251853], MSE = 43.97
# Iteration #278: W_new = [45.06240246  3.81251769], MSE = 43.97
# Iteration #279: W_new = [45.06240691  3.81251688], MSE = 43.97
# Iteration #280: W_new = [45.06241116  3.81251611], MSE = 43.97
# Iteration #281: W_new = [45.06241521  3.81251538], MSE = 43.97
# Iteration #282: W_new = [45.06241907  3.81251467], MSE = 43.97
# Iteration #283: W_new = [45.06242276  3.81251401], MSE = 43.97
# Iteration #284: W_new = [45.06242629  3.81251337], MSE = 43.97
# Iteration #285: W_new = [45.06242965  3.81251276], MSE = 43.97
# Iteration #286: W_new = [45.06243286  3.81251218], MSE = 43.97
# Iteration #287: W_new = [45.06243592  3.81251162], MSE = 43.97
# Iteration #288: W_new = [45.06243884  3.81251109], MSE = 43.97
# Iteration #289: W_new = [45.06244163  3.81251058], MSE = 43.97
# Iteration #290: W_new = [45.06244429  3.8125101 ], MSE = 43.97
# Iteration #291: W_new = [45.06244683  3.81250964], MSE = 43.97
# Iteration #292: W_new = [45.06244926  3.8125092 ], MSE = 43.97
# Iteration #293: W_new = [45.06245157  3.81250878], MSE = 43.97
# Iteration #294: W_new = [45.06245378  3.81250838], MSE = 43.97
# Iteration #295: W_new = [45.06245589  3.812508  ], MSE = 43.97
# Iteration #296: W_new = [45.0624579   3.81250763], MSE = 43.97
# Iteration #297: W_new = [45.06245982  3.81250729], MSE = 43.97
# Iteration #298: W_new = [45.06246165  3.81250695], MSE = 43.97
# Iteration #299: W_new = [45.0624634   3.81250664], MSE = 43.97
# Iteration #300: W_new = [45.06246507  3.81250633], MSE = 43.97
# Iteration #301: W_new = [45.06246666  3.81250605], MSE = 43.97
# Iteration #302: W_new = [45.06246818  3.81250577], MSE = 43.97
# Iteration #303: W_new = [45.06246963  3.81250551], MSE = 43.97
# Iteration #304: W_new = [45.06247102  3.81250526], MSE = 43.97
# Iteration #305: W_new = [45.06247234  3.81250502], MSE = 43.97
# Iteration #306: W_new = [45.0624736   3.81250479], MSE = 43.97
# Iteration #307: W_new = [45.0624748   3.81250457], MSE = 43.97
# Iteration #308: W_new = [45.06247595  3.81250436], MSE = 43.97
# Iteration #309: W_new = [45.06247705  3.81250416], MSE = 43.97
# Iteration #310: W_new = [45.06247809  3.81250397], MSE = 43.97
# Iteration #311: W_new = [45.06247909  3.81250379], MSE = 43.97
# Iteration #312: W_new = [45.06248005  3.81250362], MSE = 43.97
# Iteration #313: W_new = [45.06248096  3.81250345], MSE = 43.97
# Iteration #314: W_new = [45.06248183  3.8125033 ], MSE = 43.97
# Iteration #315: W_new = [45.06248265  3.81250315], MSE = 43.97
# Iteration #316: W_new = [45.06248345  3.812503  ], MSE = 43.97
# Iteration #317: W_new = [45.0624842   3.81250287], MSE = 43.97
# Iteration #318: W_new = [45.06248492  3.81250273], MSE = 43.97
# Iteration #319: W_new = [45.06248561  3.81250261], MSE = 43.97
# Iteration #320: W_new = [45.06248626  3.81250249], MSE = 43.97
# Iteration #321: W_new = [45.06248689  3.81250238], MSE = 43.97
# Iteration #322: W_new = [45.06248749  3.81250227], MSE = 43.97
# Iteration #323: W_new = [45.06248806  3.81250217], MSE = 43.97
# Iteration #324: W_new = [45.0624886   3.81250207], MSE = 43.97
# Iteration #325: W_new = [45.06248912  3.81250197], MSE = 43.97
# Iteration #326: W_new = [45.06248962  3.81250188], MSE = 43.97
# Iteration #327: W_new = [45.06249009  3.8125018 ], MSE = 43.97
# Iteration #328: W_new = [45.06249054  3.81250171], MSE = 43.97
# Iteration #329: W_new = [45.06249098  3.81250164], MSE = 43.97
# Iteration #330: W_new = [45.06249139  3.81250156], MSE = 43.97
# Iteration #331: W_new = [45.06249178  3.81250149], MSE = 43.97
# Iteration #332: W_new = [45.06249215  3.81250142], MSE = 43.97
# Iteration #333: W_new = [45.06249251  3.81250136], MSE = 43.97
# Iteration #334: W_new = [45.06249285  3.8125013 ], MSE = 43.97
# Iteration #335: W_new = [45.06249318  3.81250124], MSE = 43.97
# Iteration #336: W_new = [45.06249349  3.81250118], MSE = 43.97
# Iteration #337: W_new = [45.06249379  3.81250113], MSE = 43.97
# Iteration #338: W_new = [45.06249407  3.81250108], MSE = 43.97
# Iteration #339: W_new = [45.06249434  3.81250103], MSE = 43.97
# Iteration #340: W_new = [45.0624946   3.81250098], MSE = 43.97
# Iteration #341: W_new = [45.06249485  3.81250093], MSE = 43.97
# Iteration #342: W_new = [45.06249508  3.81250089], MSE = 43.97
# Iteration #343: W_new = [45.0624953   3.81250085], MSE = 43.97
# Iteration #344: W_new = [45.06249552  3.81250081], MSE = 43.97
# Iteration #345: W_new = [45.06249572  3.81250078], MSE = 43.97
# Iteration #346: W_new = [45.06249592  3.81250074], MSE = 43.97
# Iteration #347: W_new = [45.0624961   3.81250071], MSE = 43.97
# Iteration #348: W_new = [45.06249628  3.81250067], MSE = 43.97
# Iteration #349: W_new = [45.06249645  3.81250064], MSE = 43.97
# Iteration #350: W_new = [45.06249661  3.81250061], MSE = 43.97
# Iteration #351: W_new = [45.06249677  3.81250059], MSE = 43.97
# Iteration #352: W_new = [45.06249692  3.81250056], MSE = 43.97
# Iteration #353: W_new = [45.06249706  3.81250053], MSE = 43.97
# Iteration #354: W_new = [45.06249719  3.81250051], MSE = 43.97
# Iteration #355: W_new = [45.06249732  3.81250049], MSE = 43.97
# Iteration #356: W_new = [45.06249744  3.81250046], MSE = 43.97
# Iteration #357: W_new = [45.06249756  3.81250044], MSE = 43.97
# Iteration #358: W_new = [45.06249767  3.81250042], MSE = 43.97
# Iteration #359: W_new = [45.06249777  3.8125004 ], MSE = 43.97
# Iteration #360: W_new = [45.06249788  3.81250039], MSE = 43.97
# Iteration #361: W_new = [45.06249797  3.81250037], MSE = 43.97
